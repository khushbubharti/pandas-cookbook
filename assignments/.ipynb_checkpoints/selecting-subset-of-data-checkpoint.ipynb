# %%
import pandas as pd 
df = pd.read_csv('../data/college.csv',index_col = 'INSTNM')

# %%
df2 = df['CITY']
df2
# Out:
# INSTNM
# Alabama A & M University                                            Normal
# University of Alabama at Birmingham                             Birmingham
# Amridge University                                              Montgomery
# University of Alabama in Huntsville                             Huntsville
# Alabama State University                                        Montgomery
# The University of Alabama                                       Tuscaloosa
# Central Alabama Community College                           Alexander City
# Athens State University                                             Athens
# Auburn University at Montgomery                                 Montgomery
# Auburn University                                                   Auburn
# Birmingham Southern College                                     Birmingham
# Chattahoochee Valley Community College                         Phenix City
# ...

# %%
df2.iloc[6]
# Out:
# 'Alexander City'

# %%
df2.iloc[[6,7,89]]
# Out:
# INSTNM
# Central Alabama Community College            Alexander City
# Athens State University                              Athens
# Cochise County Community College District           Douglas
# Name: CITY, dtype: object

# %%
df2.iloc[6:16]
# Out:
# INSTNM
# Central Alabama Community College           Alexander City
# Athens State University                             Athens
# Auburn University at Montgomery                 Montgomery
# Auburn University                                   Auburn
# Birmingham Southern College                     Birmingham
# Chattahoochee Valley Community College         Phenix City
# Concordia College Alabama                            Selma
# South University-Montgomery                     Montgomery
# Enterprise State Community College              Enterprise
# James H Faulkner State Community College       Bay Minette
# Name: CITY, dtype: object

# %%
df2.iloc[6:18:2]
# Out:
# INSTNM
# Central Alabama Community College     Alexander City
# Auburn University at Montgomery           Montgomery
# Birmingham Southern College               Birmingham
# Concordia College Alabama                      Selma
# Enterprise State Community College        Enterprise
# Faulkner University                       Montgomery
# Name: CITY, dtype: object

# %%
df2.loc['Birmingham Southern College']
# Out:
# 'Birmingham'

# %%
df2.loc[['Birmingham Southern College','Enterprise State Community College']]
# Out:
# INSTNM
# Birmingham Southern College           Birmingham
# Enterprise State Community College    Enterprise
# Name: CITY, dtype: object

# %%
df.iloc[6]
# Out:
# CITY                  Alexander City
# STABBR                            AL
# HBCU                               0
# MENONLY                            0
# WOMENONLY                          0
# RELAFFIL                           0
# SATVRMID                         NaN
# SATMTMID                         NaN
# DISTANCEONLY                       0
# UGDS                            1592
# UGDS_WHITE                    0.7255
# UGDS_BLACK                    0.2613
# UGDS_HISP                     0.0044
# UGDS_ASIAN                    0.0025
# UGDS_AIAN                     0.0044
# UGDS_NHPI                          0
# UGDS_2MOR                          0
# UGDS_NRA                           0
# UGDS_UNKN                     0.0019
# PPTUG_EF                      0.3882
# CURROPER                           1
# PCTPELL                       0.5892
# PCTFLOAN                      0.3977
# UG25ABV                       0.3153
# MD_EARN_WNE_P10                27500
# ...

# %%
df.iloc[[6,7,89]]
# Out:
#                                                      CITY STABBR  HBCU  \
# INSTNM
# Central Alabama Community College          Alexander City     AL   0.0
# Athens State University                            Athens     AL   0.0
# Cochise County Community College District         Douglas     AZ   0.0
#
#                                            MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Central Alabama Community College              0.0        0.0         0
# Athens State University                        0.0        0.0         0
# Cochise County Community College District      0.0        0.0         0
#
#                                            SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# Central Alabama Community College               NaN       NaN           0.0
# Athens State University                         NaN       NaN           0.0
# Cochise County Community College District       NaN       NaN           0.0
#
# ...

# %%
df.iloc[6:16]
# Out:
#                                                     CITY STABBR  HBCU  \
# INSTNM
# Central Alabama Community College         Alexander City     AL   0.0
# Athens State University                           Athens     AL   0.0
# Auburn University at Montgomery               Montgomery     AL   0.0
# Auburn University                                 Auburn     AL   0.0
# Birmingham Southern College                   Birmingham     AL   0.0
# Chattahoochee Valley Community College       Phenix City     AL   0.0
# Concordia College Alabama                          Selma     AL   1.0
# South University-Montgomery                   Montgomery     AL   0.0
# Enterprise State Community College            Enterprise     AL   0.0
# James H Faulkner State Community College     Bay Minette     AL   0.0
#
#                                           MENONLY  WOMENONLY  RELAFFIL  \
# INSTNM
# Central Alabama Community College             0.0        0.0         0
# ...

# %%
df.iloc[:,4:9:2]
# Out:
#                                                     WOMENONLY  SATVRMID  \
# INSTNM
# Alabama A & M University                                  0.0     424.0
# University of Alabama at Birmingham                       0.0     570.0
# Amridge University                                        0.0       NaN
# University of Alabama in Huntsville                       0.0     595.0
# Alabama State University                                  0.0     425.0
# The University of Alabama                                 0.0     555.0
# Central Alabama Community College                         0.0       NaN
# Athens State University                                   0.0       NaN
# Auburn University at Montgomery                           0.0     486.0
# Auburn University                                         0.0     575.0
# Birmingham Southern College                               0.0     560.0
# Chattahoochee Valley Community College                    0.0       NaN
# ...

# %%
df.loc[:,['WOMENONLY','SATVRMID','DISTANCEONLY']]
# Out:
#                                                     WOMENONLY  SATVRMID  \
# INSTNM
# Alabama A & M University                                  0.0     424.0
# University of Alabama at Birmingham                       0.0     570.0
# Amridge University                                        0.0       NaN
# University of Alabama in Huntsville                       0.0     595.0
# Alabama State University                                  0.0     425.0
# The University of Alabama                                 0.0     555.0
# Central Alabama Community College                         0.0       NaN
# Athens State University                                   0.0       NaN
# Auburn University at Montgomery                           0.0     486.0
# Auburn University                                         0.0     575.0
# Birmingham Southern College                               0.0     560.0
# Chattahoochee Valley Community College                    0.0       NaN
# ...

# %%
df[['WOMENONLY','SATVRMID','DISTANCEONLY']]
# Out:
#                                                     WOMENONLY  SATVRMID  \
# INSTNM
# Alabama A & M University                                  0.0     424.0
# University of Alabama at Birmingham                       0.0     570.0
# Amridge University                                        0.0       NaN
# University of Alabama in Huntsville                       0.0     595.0
# Alabama State University                                  0.0     425.0
# The University of Alabama                                 0.0     555.0
# Central Alabama Community College                         0.0       NaN
# Athens State University                                   0.0       NaN
# Auburn University at Montgomery                           0.0     486.0
# Auburn University                                         0.0     575.0
# Birmingham Southern College                               0.0     560.0
# Chattahoochee Valley Community College                    0.0       NaN
# ...

# %%
df.filter(items=['WOMENONLY','SATVRMID','DISTANCEONLY'])
# Out:
#                                                     WOMENONLY  SATVRMID  \
# INSTNM
# Alabama A & M University                                  0.0     424.0
# University of Alabama at Birmingham                       0.0     570.0
# Amridge University                                        0.0       NaN
# University of Alabama in Huntsville                       0.0     595.0
# Alabama State University                                  0.0     425.0
# The University of Alabama                                 0.0     555.0
# Central Alabama Community College                         0.0       NaN
# Athens State University                                   0.0       NaN
# Auburn University at Montgomery                           0.0     486.0
# Auburn University                                         0.0     575.0
# Birmingham Southern College                               0.0     560.0
# Chattahoochee Valley Community College                    0.0       NaN
# ...

# %%
df.loc[:,'WOMENONLY']
# Out:
# INSTNM
# Alabama A & M University                                  0.0
# University of Alabama at Birmingham                       0.0
# Amridge University                                        0.0
# University of Alabama in Huntsville                       0.0
# Alabama State University                                  0.0
# The University of Alabama                                 0.0
# Central Alabama Community College                         0.0
# Athens State University                                   0.0
# Auburn University at Montgomery                           0.0
# Auburn University                                         0.0
# Birmingham Southern College                               0.0
# Chattahoochee Valley Community College                    0.0
# Concordia College Alabama                                 0.0
# South University-Montgomery                               0.0
# Enterprise State Community College                        0.0
# ...

# %%
df['WOMENONLY']
# Out:
# INSTNM
# Alabama A & M University                                  0.0
# University of Alabama at Birmingham                       0.0
# Amridge University                                        0.0
# University of Alabama in Huntsville                       0.0
# Alabama State University                                  0.0
# The University of Alabama                                 0.0
# Central Alabama Community College                         0.0
# Athens State University                                   0.0
# Auburn University at Montgomery                           0.0
# Auburn University                                         0.0
# Birmingham Southern College                               0.0
# Chattahoochee Valley Community College                    0.0
# Concordia College Alabama                                 0.0
# South University-Montgomery                               0.0
# Enterprise State Community College                        0.0
# ...

# %%
df=df.sort_index()
df
# Out:
#                                                                 CITY STABBR  \
# INSTNM
# A & W Healthcare Educators                               New Orleans     LA
# A T Still University of Health Sciences                   Kirksville     MO
# ABC Beauty Academy                                           Garland     TX
# ABC Beauty College Inc                                   Arkadelphia     AR
# AI Miami International University of Art and De...             Miami     FL
# AIB College of Business                                   Des Moines     IA
# AOMA Graduate School of Integrative Medicine                  Austin     TX
# ASA College                                                 Brooklyn     NY
# ASI Career Institute                                    Turnersville     NJ
# ASM Beauty World Academy                                       Davie     FL
# ATA Career Education                                     Spring Hill     FL
# ...

# %%
df.loc['A':'C']
# Out:
#                                                                 CITY STABBR  \
# INSTNM
# A & W Healthcare Educators                               New Orleans     LA
# A T Still University of Health Sciences                   Kirksville     MO
# ABC Beauty Academy                                           Garland     TX
# ABC Beauty College Inc                                   Arkadelphia     AR
# AI Miami International University of Art and De...             Miami     FL
# AIB College of Business                                   Des Moines     IA
# AOMA Graduate School of Integrative Medicine                  Austin     TX
# ASA College                                                 Brooklyn     NY
# ASI Career Institute                                    Turnersville     NJ
# ASM Beauty World Academy                                       Davie     FL
# ATA Career Education                                     Spring Hill     FL
# ...
