# %% [markdown]
# Q.1.Explain the use of following DataFrame attributes with example.

# %%
import pandas as pd
movie = pd.read_csv('movie.csv')
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0       Rory Kinner
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
import pandas as pd
movie = pd.read_csv('movie.csv')
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0       Rory Kinner
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
#(a)
movie.index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
#(b)
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#(c)
movie.values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
#(d)
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# Q.2. Explain the use of following dataframe methods with examples.

# %%
#(a)
movie.get_dtype_counts()
# Out:
# float64    13
# int64       3
# object     12
# dtype: int64

# %%
#(b)
movie1 =movie['director_name']
movie1.to_frame()
# Out:
#            director_name
# 0          James Cameron
# 1         Gore Verbinski
# 2             Sam Mendes
# 3      Christopher Nolan
# 4            Doug Walker
# 5         Andrew Stanton
# 6              Sam Raimi
# 7           Nathan Greno
# 8            Joss Whedon
# 9            David Yates
# 10           Zack Snyder
# 11          Bryan Singer
# 12          Marc Forster
# 13        Gore Verbinski
# 14        Gore Verbinski
# 15           Zack Snyder
# 16        Andrew Adamson
# 17           Joss Whedon
# 18          Rob Marshall
# 19      Barry Sonnenfeld
# 20         Peter Jackson
# 21             Marc Webb
# 22          Ridley Scott
# 23         Peter Jackson
# 24           Chris Weitz
# 25         Peter Jackson
# 26         James Cameron
# 27         Anthony Russo
# 28            Peter Berg
# 29       Colin Trevorrow
# ...                  ...
# 4886          Eric Eason
# 4887            Uwe Boll
# 4888   Richard Linklater
# 4889     Joseph Mazzella
# 4890        Travis Legge
# ...

# %%
print(type(movie))
type(movie1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# pandas.core.series.Series

# %%
movie = pd.read_csv('movie.csv')
movie = movie.iloc[[3]].T
#movie.to_frame()
movie
# Out:
#                                                                            3
# color                                                                  Color
# director_name                                              Christopher Nolan
# num_critic_for_reviews                                                   813
# duration                                                                 164
# director_facebook_likes                                                22000
# actor_3_facebook_likes                                                 23000
# actor_2_name                                                  Christian Bale
# actor_1_facebook_likes                                                 27000
# gross                                                            4.48131e+08
# genres                                                       Action|Thriller
# actor_1_name                                                       Tom Hardy
# ...

# %%
#(c)
movie = pd.read_csv('movie.csv')
movie2 = movie.set_index('movie_title')
movie2
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
#(d)
movie3 = movie.reset_index()
movie3
# Out:
#       index            color       director_name  num_critic_for_reviews  \
# 0         0            Color       James Cameron                   723.0
# 1         1            Color      Gore Verbinski                   302.0
# 2         2            Color          Sam Mendes                   602.0
# 3         3            Color   Christopher Nolan                   813.0
# 4         4              NaN         Doug Walker                     NaN
# 5         5            Color      Andrew Stanton                   462.0
# 6         6            Color           Sam Raimi                   392.0
# 7         7            Color        Nathan Greno                   324.0
# 8         8            Color         Joss Whedon                   635.0
# 9         9            Color         David Yates                   375.0
# 10       10            Color         Zack Snyder                   673.0
# 11       11            Color        Bryan Singer                   434.0
# ...

# %% [markdown]
# Q.3.How can you select a series of data from DataFrame. Explain with the help of an example.

# %% [markdown]
# Ans.There are two ways of selecting a series of data from DataFrame.
# (a)Selecting a row
# (b)Projecting a columns

# %%
#(a)
movie_series = movie.loc[3]
movie_series
# Out:
# color                                                                    Color
# director_name                                                Christopher Nolan
# num_critic_for_reviews                                                     813
# duration                                                                   164
# director_facebook_likes                                                  22000
# actor_3_facebook_likes                                                   23000
# actor_2_name                                                    Christian Bale
# actor_1_facebook_likes                                                   27000
# gross                                                              4.48131e+08
# genres                                                         Action|Thriller
# actor_1_name                                                         Tom Hardy
# movie_title                                              The Dark Knight Rises
# ...

# %%
#(b)
movie_col =movie['director_name']
movie_col
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# 4888     Richard Linklater
# ...

# %%
type(movie_col)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Q.4.Explain the use of following series with example.

# %%
#(a)
import pandas as pd
s_att_methods = set(dir(pd.Series))
len(s_att_methods)
# Out:
# 471

# %%
#(b)
# Out:
# Steven Spielberg        26
# Woody Allen             22
# Martin Scorsese         20
# Clint Eastwood          20
# Spike Lee               16
# Ridley Scott            16
# Steven Soderbergh       15
# Renny Harlin            15
# Oliver Stone            14
# Tim Burton              14
# Joel Schumacher         13
# Ron Howard              13
# Robert Zemeckis         13
# Barry Levinson          13
# Robert Rodriguez        13
# Brian De Palma          12
# Michael Bay             12
# Kevin Smith             12
# Tony Scott              12
# Francis Ford Coppola    11
# Richard Linklater       11
# Shawn Levy              11
# Rob Reiner              11
# Sam Raimi               11
# Richard Donner          11
# Chris Columbus          11
# David Fincher           10
# John Carpenter          10
# Bobby Farrelly          10
# John McTiernan          10
#                         ..
# Melville Shavelson       1
# Antonio Simoncini        1
# Bob Gosse                1
# ...

# %%
#(c)
director.count()
# Out:
# 4814

# %%
#(a)
len(director)
# Out:
# 4916

# %%
#(d)
actor_1_fb_likes = movie['actor_1_facebook_likes']
actor_1_fb_likes.min()
# Out:
# 0.0

# %%
#(e)
actor_1_fb_likes.max()
# Out:
# 640000.0

# %%
#(f)
actor_1_fb_likes.mean()
# Out:
# 6494.488490527602

# %%
#(g)
actor_1_fb_likes.median()
# Out:
# 982.0

# %%
#(h)
actor_1_fb_likes.std()
# Out:
# 15106.986883848309

# %%
#(i)
actor_1_fb_likes.sum()
# Out:
# 31881444.0

# %%
#(j)
actor_1_fb_likes.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
#(k)
actor_1_fb_likes.quantile(.2)
# Out:
# 510.0

# %%
#(l)
director.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4886    False
# 4887    False
# 4888    False
# 4889    False
# 4890    False
# 4891    False
# 4892    False
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902    False
# 4903    False
# 4904    False
# 4905    False
# 4906    False
# 4907    False
# 4908    False
# 4909    False
# 4910    False
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
#(m) It is possible to replace all missing values within a Series with the fillna method: 
actor_filled = actor_1_fb_likes.fillna(0)
actor_filled.count()
# Out:
# 4916

# %%
#(n)To remove the series elements with missing values, use dropna:
actor_drop = actor_1_fb_likes.dropna()
actor_drop.count()
# Out:
# 4909

# %%
#(o)The notnull method, which return True for all the non-missing values:
director.notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 4886     True
# 4887     True
# 4888     True
# 4889     True
# 4890     True
# 4891     True
# 4892     True
# 4893     True
# 4894     True
# 4895     True
# 4896     True
# 4897     True
# 4898     True
# 4899     True
# 4900     True
# 4901     True
# 4902     True
# 4903     True
# 4904     True
# 4905     True
# 4906     True
# 4907     True
# 4908     True
# 4909     True
# 4910     True
# 4911     True
# 4912    False
# 4913     True
# 4914     True
# 4915     True
# ...

# %% [markdown]
# Q.5.Explain the use of folloeing series attributes with example:

# %%
#(a)Counting the number of elements in the series may be done with the size or shape parameter or the len function
director.size
# Out:
# 4916

# %%
#(b)
director.shape
# Out:
# (4916,)

# %%
#(c)Missing value in the series by observing that the result from the count method did not match the size attributes.
#A more direct approch is to use the hasnans attributes
director.hasnans
# Out:
# True

# %% [markdown]
#  Q.6.Explain the following series methods with examples

# %%
imdb_score = movie['imdb_score']
imdb_score
# Out:
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
# 5       6.6
# 6       6.2
# 7       7.8
# 8       7.5
# 9       7.5
# 10      6.9
# 11      6.1
# 12      6.7
# 13      7.3
# 14      6.5
# 15      7.2
# 16      6.6
# 17      8.1
# 18      6.7
# 19      6.8
# 20      7.5
# 21      7.0
# 22      6.7
# 23      7.9
# 24      6.1
# 25      7.2
# 26      7.7
# 27      8.2
# 28      5.9
# 29      7.0
#        ...
# 4886    7.0
# 4887    6.3
# 4888    7.1
# 4889    4.8
# 4890    3.3
# 4891    6.9
# 4892    4.6
# 4893    3.0
# 4894    6.6
# 4895    7.4
# 4896    6.2
# 4897    4.0
# 4898    6.1
# 4899    6.9
# 4900    7.5
# 4901    6.7
# 4902    7.4
# 4903    6.1
# 4904    5.4
# 4905    6.4
# 4906    7.0
# 4907    6.3
# 4908    6.9
# 4909    7.8
# 4910    6.4
# 4911    7.7
# 4912    7.5
# 4913    6.3
# 4914    6.3
# 4915    6.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#(a)
imdb_score.add(1)
# Out:
# 0       8.9
# 1       8.1
# 2       7.8
# 3       9.5
# 4       8.1
# 5       7.6
# 6       7.2
# 7       8.8
# 8       8.5
# 9       8.5
# 10      7.9
# 11      7.1
# 12      7.7
# 13      8.3
# 14      7.5
# 15      8.2
# 16      7.6
# 17      9.1
# 18      7.7
# 19      7.8
# 20      8.5
# 21      8.0
# 22      7.7
# 23      8.9
# 24      7.1
# 25      8.2
# 26      8.7
# 27      9.2
# 28      6.9
# 29      8.0
#        ...
# 4886    8.0
# 4887    7.3
# 4888    8.1
# 4889    5.8
# 4890    4.3
# 4891    7.9
# 4892    5.6
# 4893    4.0
# 4894    7.6
# 4895    8.4
# 4896    7.2
# 4897    5.0
# 4898    7.1
# 4899    7.9
# 4900    8.5
# 4901    7.7
# 4902    8.4
# 4903    7.1
# 4904    6.4
# 4905    7.4
# 4906    8.0
# 4907    7.3
# 4908    7.9
# 4909    8.8
# 4910    7.4
# 4911    8.7
# 4912    8.5
# 4913    7.3
# 4914    7.3
# 4915    7.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#(b)
imdb_score.mul(2)
# Out:
# 0       15.8
# 1       14.2
# 2       13.6
# 3       17.0
# 4       14.2
# 5       13.2
# 6       12.4
# 7       15.6
# 8       15.0
# 9       15.0
# 10      13.8
# 11      12.2
# 12      13.4
# 13      14.6
# 14      13.0
# 15      14.4
# 16      13.2
# 17      16.2
# 18      13.4
# 19      13.6
# 20      15.0
# 21      14.0
# 22      13.4
# 23      15.8
# 24      12.2
# 25      14.4
# 26      15.4
# 27      16.4
# 28      11.8
# 29      14.0
#         ...
# 4886    14.0
# 4887    12.6
# 4888    14.2
# 4889     9.6
# 4890     6.6
# 4891    13.8
# 4892     9.2
# 4893     6.0
# 4894    13.2
# 4895    14.8
# 4896    12.4
# 4897     8.0
# 4898    12.2
# 4899    13.8
# 4900    15.0
# 4901    13.4
# 4902    14.8
# 4903    12.2
# 4904    10.8
# 4905    12.8
# 4906    14.0
# 4907    12.6
# 4908    13.8
# 4909    15.6
# 4910    12.8
# 4911    15.4
# 4912    15.0
# 4913    12.6
# 4914    12.6
# 4915    13.2
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#(c)
imdb_score.floordiv(6)
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# 5       1.0
# 6       1.0
# 7       1.0
# 8       1.0
# 9       1.0
# 10      1.0
# 11      1.0
# 12      1.0
# 13      1.0
# 14      1.0
# 15      1.0
# 16      1.0
# 17      1.0
# 18      1.0
# 19      1.0
# 20      1.0
# 21      1.0
# 22      1.0
# 23      1.0
# 24      1.0
# 25      1.0
# 26      1.0
# 27      1.0
# 28      0.0
# 29      1.0
#        ...
# 4886    1.0
# 4887    1.0
# 4888    1.0
# 4889    0.0
# 4890    0.0
# 4891    1.0
# 4892    0.0
# 4893    0.0
# 4894    1.0
# 4895    1.0
# 4896    1.0
# 4897    0.0
# 4898    1.0
# 4899    1.0
# 4900    1.0
# 4901    1.0
# 4902    1.0
# 4903    1.0
# 4904    0.0
# 4905    1.0
# 4906    1.0
# 4907    1.0
# 4908    1.0
# 4909    1.0
# 4910    1.0
# 4911    1.0
# 4912    1.0
# 4913    1.0
# 4914    1.0
# 4915    1.0
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score.gt(7)
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
# 5       False
# 6       False
# 7        True
# 8        True
# 9        True
# 10      False
# 11      False
# 12      False
# 13       True
# 14      False
# 15       True
# 16      False
# 17       True
# 18      False
# 19      False
# 20       True
# 21      False
# 22      False
# 23       True
# 24      False
# 25       True
# 26       True
# 27       True
# 28      False
# 29      False
#         ...
# 4886    False
# 4887    False
# 4888     True
# 4889    False
# 4890    False
# 4891    False
# 4892    False
# 4893    False
# 4894    False
# 4895     True
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# 4900     True
# 4901    False
# 4902     True
# 4903    False
# 4904    False
# 4905    False
# 4906    False
# 4907    False
# 4908    False
# 4909     True
# 4910    False
# 4911     True
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
#(e)
imdb_score.eq(6)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4886    False
# 4887    False
# 4888    False
# 4889    False
# 4890    False
# 4891    False
# 4892    False
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902    False
# 4903    False
# 4904    False
# 4905    False
# 4906    False
# 4907    False
# 4908    False
# 4909    False
# 4910    False
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
#(f)
imdb_score.mod(6)
# Out:
# 0       1.9
# 1       1.1
# 2       0.8
# 3       2.5
# 4       1.1
# 5       0.6
# 6       0.2
# 7       1.8
# 8       1.5
# 9       1.5
# 10      0.9
# 11      0.1
# 12      0.7
# 13      1.3
# 14      0.5
# 15      1.2
# 16      0.6
# 17      2.1
# 18      0.7
# 19      0.8
# 20      1.5
# 21      1.0
# 22      0.7
# 23      1.9
# 24      0.1
# 25      1.2
# 26      1.7
# 27      2.2
# 28      5.9
# 29      1.0
#        ...
# 4886    1.0
# 4887    0.3
# 4888    1.1
# 4889    4.8
# 4890    3.3
# 4891    0.9
# 4892    4.6
# 4893    3.0
# 4894    0.6
# 4895    1.4
# 4896    0.2
# 4897    4.0
# 4898    0.1
# 4899    0.9
# 4900    1.5
# 4901    0.7
# 4902    1.4
# 4903    0.1
# 4904    5.4
# 4905    0.4
# 4906    1.0
# 4907    0.3
# 4908    0.9
# 4909    1.8
# 4910    0.4
# 4911    1.7
# 4912    1.5
# 4913    0.3
# 4914    0.3
# 4915    0.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#(g)
imdb_score.pow(2)
# Out:
# 0       62.41
# 1       50.41
# 2       46.24
# 3       72.25
# 4       50.41
# 5       43.56
# 6       38.44
# 7       60.84
# 8       56.25
# 9       56.25
# 10      47.61
# 11      37.21
# 12      44.89
# 13      53.29
# 14      42.25
# 15      51.84
# 16      43.56
# 17      65.61
# 18      44.89
# 19      46.24
# 20      56.25
# 21      49.00
# 22      44.89
# 23      62.41
# 24      37.21
# 25      51.84
# 26      59.29
# 27      67.24
# 28      34.81
# 29      49.00
#         ...
# 4886    49.00
# 4887    39.69
# 4888    50.41
# 4889    23.04
# 4890    10.89
# 4891    47.61
# 4892    21.16
# 4893     9.00
# 4894    43.56
# 4895    54.76
# 4896    38.44
# 4897    16.00
# 4898    37.21
# 4899    47.61
# 4900    56.25
# 4901    44.89
# 4902    54.76
# 4903    37.21
# 4904    29.16
# 4905    40.96
# 4906    49.00
# 4907    39.69
# 4908    47.61
# 4909    60.84
# 4910    40.96
# 4911    59.29
# 4912    56.25
# 4913    39.69
# 4914    39.69
# 4915    43.56
# ...

# %%
#(h)
imdb_score.lt(5)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4886    False
# 4887    False
# 4888    False
# 4889     True
# 4890     True
# 4891    False
# 4892     True
# 4893     True
# 4894    False
# 4895    False
# 4896    False
# 4897     True
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902    False
# 4903    False
# 4904    False
# 4905    False
# 4906    False
# 4907    False
# 4908    False
# 4909    False
# 4910    False
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
#(i)
imdb_score.le(7)
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
# 5        True
# 6        True
# 7       False
# 8       False
# 9       False
# 10       True
# 11       True
# 12       True
# 13      False
# 14       True
# 15      False
# 16       True
# 17      False
# 18       True
# 19       True
# 20      False
# 21       True
# 22       True
# 23      False
# 24       True
# 25      False
# 26      False
# 27      False
# 28       True
# 29       True
#         ...
# 4886     True
# 4887     True
# 4888    False
# 4889     True
# 4890     True
# 4891     True
# 4892     True
# 4893     True
# 4894     True
# 4895    False
# 4896     True
# 4897     True
# 4898     True
# 4899     True
# 4900    False
# 4901     True
# 4902    False
# 4903     True
# 4904     True
# 4905     True
# 4906     True
# 4907     True
# 4908     True
# 4909    False
# 4910     True
# 4911    False
# 4912    False
# 4913     True
# 4914     True
# 4915     True
# ...

# %%
#(j)
imdb_score.ge(7)
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
# 5       False
# 6       False
# 7        True
# 8        True
# 9        True
# 10      False
# 11      False
# 12      False
# 13       True
# 14      False
# 15       True
# 16      False
# 17       True
# 18      False
# 19      False
# 20       True
# 21       True
# 22      False
# 23       True
# 24      False
# 25       True
# 26       True
# 27       True
# 28      False
# 29       True
#         ...
# 4886     True
# 4887    False
# 4888     True
# 4889    False
# 4890    False
# 4891    False
# 4892    False
# 4893    False
# 4894    False
# 4895     True
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# 4900     True
# 4901    False
# 4902     True
# 4903    False
# 4904    False
# 4905    False
# 4906     True
# 4907    False
# 4908    False
# 4909     True
# 4910    False
# 4911     True
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
#(k)
imdb_score.eq(7)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21       True
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29       True
#         ...
# 4886     True
# 4887    False
# 4888    False
# 4889    False
# 4890    False
# 4891    False
# 4892    False
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902    False
# 4903    False
# 4904    False
# 4905    False
# 4906     True
# 4907    False
# 4908    False
# 4909    False
# 4910    False
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
#(l)
imdb_score.ne(7)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21      False
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29      False
#         ...
# 4886    False
# 4887     True
# 4888     True
# 4889     True
# 4890     True
# 4891     True
# 4892     True
# 4893     True
# 4894     True
# 4895     True
# 4896     True
# 4897     True
# 4898     True
# 4899     True
# 4900     True
# 4901     True
# 4902     True
# 4903     True
# 4904     True
# 4905     True
# 4906    False
# 4907     True
# 4908     True
# 4909     True
# 4910     True
# 4911     True
# 4912     True
# 4913     True
# 4914     True
# 4915     True
# ...

# %% [markdown]
# Q.7.Demonstrate the use of following operator on series using an example for use.

# %%
#(a)
imdb_score + 1
# Out:
# 0       8.9
# 1       8.1
# 2       7.8
# 3       9.5
# 4       8.1
# 5       7.6
# 6       7.2
# 7       8.8
# 8       8.5
# 9       8.5
# 10      7.9
# 11      7.1
# 12      7.7
# 13      8.3
# 14      7.5
# 15      8.2
# 16      7.6
# 17      9.1
# 18      7.7
# 19      7.8
# 20      8.5
# 21      8.0
# 22      7.7
# 23      8.9
# 24      7.1
# 25      8.2
# 26      8.7
# 27      9.2
# 28      6.9
# 29      8.0
#        ...
# 4886    8.0
# 4887    7.3
# 4888    8.1
# 4889    5.8
# 4890    4.3
# 4891    7.9
# 4892    5.6
# 4893    4.0
# 4894    7.6
# 4895    8.4
# 4896    7.2
# 4897    5.0
# 4898    7.1
# 4899    7.9
# 4900    8.5
# 4901    7.7
# 4902    8.4
# 4903    7.1
# 4904    6.4
# 4905    7.4
# 4906    8.0
# 4907    7.3
# 4908    7.9
# 4909    8.8
# 4910    7.4
# 4911    8.7
# 4912    8.5
# 4913    7.3
# 4914    7.3
# 4915    7.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#(b)
imdb_score - 1
# Out:
# 0       6.9
# 1       6.1
# 2       5.8
# 3       7.5
# 4       6.1
# 5       5.6
# 6       5.2
# 7       6.8
# 8       6.5
# 9       6.5
# 10      5.9
# 11      5.1
# 12      5.7
# 13      6.3
# 14      5.5
# 15      6.2
# 16      5.6
# 17      7.1
# 18      5.7
# 19      5.8
# 20      6.5
# 21      6.0
# 22      5.7
# 23      6.9
# 24      5.1
# 25      6.2
# 26      6.7
# 27      7.2
# 28      4.9
# 29      6.0
#        ...
# 4886    6.0
# 4887    5.3
# 4888    6.1
# 4889    3.8
# 4890    2.3
# 4891    5.9
# 4892    3.6
# 4893    2.0
# 4894    5.6
# 4895    6.4
# 4896    5.2
# 4897    3.0
# 4898    5.1
# 4899    5.9
# 4900    6.5
# 4901    5.7
# 4902    6.4
# 4903    5.1
# 4904    4.4
# 4905    5.4
# 4906    6.0
# 4907    5.3
# 4908    5.9
# 4909    6.8
# 4910    5.4
# 4911    6.7
# 4912    6.5
# 4913    5.3
# 4914    5.3
# 4915    5.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#(c)
imdb_score * 2
# Out:
# 0       15.8
# 1       14.2
# 2       13.6
# 3       17.0
# 4       14.2
# 5       13.2
# 6       12.4
# 7       15.6
# 8       15.0
# 9       15.0
# 10      13.8
# 11      12.2
# 12      13.4
# 13      14.6
# 14      13.0
# 15      14.4
# 16      13.2
# 17      16.2
# 18      13.4
# 19      13.6
# 20      15.0
# 21      14.0
# 22      13.4
# 23      15.8
# 24      12.2
# 25      14.4
# 26      15.4
# 27      16.4
# 28      11.8
# 29      14.0
#         ...
# 4886    14.0
# 4887    12.6
# 4888    14.2
# 4889     9.6
# 4890     6.6
# 4891    13.8
# 4892     9.2
# 4893     6.0
# 4894    13.2
# 4895    14.8
# 4896    12.4
# 4897     8.0
# 4898    12.2
# 4899    13.8
# 4900    15.0
# 4901    13.4
# 4902    14.8
# 4903    12.2
# 4904    10.8
# 4905    12.8
# 4906    14.0
# 4907    12.6
# 4908    13.8
# 4909    15.6
# 4910    12.8
# 4911    15.4
# 4912    15.0
# 4913    12.6
# 4914    12.6
# 4915    13.2
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#(d)
imdb_score / 7
# Out:
# 0       1.128571
# 1       1.014286
# 2       0.971429
# 3       1.214286
# 4       1.014286
# 5       0.942857
# 6       0.885714
# 7       1.114286
# 8       1.071429
# 9       1.071429
# 10      0.985714
# 11      0.871429
# 12      0.957143
# 13      1.042857
# 14      0.928571
# 15      1.028571
# 16      0.942857
# 17      1.157143
# 18      0.957143
# 19      0.971429
# 20      1.071429
# 21      1.000000
# 22      0.957143
# 23      1.128571
# 24      0.871429
# 25      1.028571
# 26      1.100000
# 27      1.171429
# 28      0.842857
# 29      1.000000
#           ...
# 4886    1.000000
# 4887    0.900000
# 4888    1.014286
# 4889    0.685714
# 4890    0.471429
# 4891    0.985714
# 4892    0.657143
# 4893    0.428571
# 4894    0.942857
# 4895    1.057143
# 4896    0.885714
# 4897    0.571429
# 4898    0.871429
# 4899    0.985714
# 4900    1.071429
# 4901    0.957143
# 4902    1.057143
# 4903    0.871429
# 4904    0.771429
# 4905    0.914286
# 4906    1.000000
# ...

# %%
#(e)
imdb_score // 7
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       1.0
# 5       0.0
# 6       0.0
# 7       1.0
# 8       1.0
# 9       1.0
# 10      0.0
# 11      0.0
# 12      0.0
# 13      1.0
# 14      0.0
# 15      1.0
# 16      0.0
# 17      1.0
# 18      0.0
# 19      0.0
# 20      1.0
# 21      1.0
# 22      0.0
# 23      1.0
# 24      0.0
# 25      1.0
# 26      1.0
# 27      1.0
# 28      0.0
# 29      1.0
#        ...
# 4886    1.0
# 4887    0.0
# 4888    1.0
# 4889    0.0
# 4890    0.0
# 4891    0.0
# 4892    0.0
# 4893    0.0
# 4894    0.0
# 4895    1.0
# 4896    0.0
# 4897    0.0
# 4898    0.0
# 4899    0.0
# 4900    1.0
# 4901    0.0
# 4902    1.0
# 4903    0.0
# 4904    0.0
# 4905    0.0
# 4906    1.0
# 4907    0.0
# 4908    0.0
# 4909    1.0
# 4910    0.0
# 4911    1.0
# 4912    1.0
# 4913    0.0
# 4914    0.0
# 4915    0.0
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#(f)
imdb_score % 4
# Out:
# 0       3.9
# 1       3.1
# 2       2.8
# 3       0.5
# 4       3.1
# 5       2.6
# 6       2.2
# 7       3.8
# 8       3.5
# 9       3.5
# 10      2.9
# 11      2.1
# 12      2.7
# 13      3.3
# 14      2.5
# 15      3.2
# 16      2.6
# 17      0.1
# 18      2.7
# 19      2.8
# 20      3.5
# 21      3.0
# 22      2.7
# 23      3.9
# 24      2.1
# 25      3.2
# 26      3.7
# 27      0.2
# 28      1.9
# 29      3.0
#        ...
# 4886    3.0
# 4887    2.3
# 4888    3.1
# 4889    0.8
# 4890    3.3
# 4891    2.9
# 4892    0.6
# 4893    3.0
# 4894    2.6
# 4895    3.4
# 4896    2.2
# 4897    0.0
# 4898    2.1
# 4899    2.9
# 4900    3.5
# 4901    2.7
# 4902    3.4
# 4903    2.1
# 4904    1.4
# 4905    2.4
# 4906    3.0
# 4907    2.3
# 4908    2.9
# 4909    3.8
# 4910    2.4
# 4911    3.7
# 4912    3.5
# 4913    2.3
# 4914    2.3
# 4915    2.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#(g)
imdb_score ** 2
# Out:
# 0       62.41
# 1       50.41
# 2       46.24
# 3       72.25
# 4       50.41
# 5       43.56
# 6       38.44
# 7       60.84
# 8       56.25
# 9       56.25
# 10      47.61
# 11      37.21
# 12      44.89
# 13      53.29
# 14      42.25
# 15      51.84
# 16      43.56
# 17      65.61
# 18      44.89
# 19      46.24
# 20      56.25
# 21      49.00
# 22      44.89
# 23      62.41
# 24      37.21
# 25      51.84
# 26      59.29
# 27      67.24
# 28      34.81
# 29      49.00
#         ...
# 4886    49.00
# 4887    39.69
# 4888    50.41
# 4889    23.04
# 4890    10.89
# 4891    47.61
# 4892    21.16
# 4893     9.00
# 4894    43.56
# 4895    54.76
# 4896    38.44
# 4897    16.00
# 4898    37.21
# 4899    47.61
# 4900    56.25
# 4901    44.89
# 4902    54.76
# 4903    37.21
# 4904    29.16
# 4905    40.96
# 4906    49.00
# 4907    39.69
# 4908    47.61
# 4909    60.84
# 4910    40.96
# 4911    59.29
# 4912    56.25
# 4913    39.69
# 4914    39.69
# 4915    43.56
# ...

# %%
#(h)
imdb_score < 7
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
# 5        True
# 6        True
# 7       False
# 8       False
# 9       False
# 10       True
# 11       True
# 12       True
# 13      False
# 14       True
# 15      False
# 16       True
# 17      False
# 18       True
# 19       True
# 20      False
# 21      False
# 22       True
# 23      False
# 24       True
# 25      False
# 26      False
# 27      False
# 28       True
# 29      False
#         ...
# 4886    False
# 4887     True
# 4888    False
# 4889     True
# 4890     True
# 4891     True
# 4892     True
# 4893     True
# 4894     True
# 4895    False
# 4896     True
# 4897     True
# 4898     True
# 4899     True
# 4900    False
# 4901     True
# 4902    False
# 4903     True
# 4904     True
# 4905     True
# 4906    False
# 4907     True
# 4908     True
# 4909    False
# 4910     True
# 4911    False
# 4912    False
# 4913     True
# 4914     True
# 4915     True
# ...

# %%
#(i)
imdb_score > 6
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28      False
# 29       True
#         ...
# 4886     True
# 4887     True
# 4888     True
# 4889    False
# 4890    False
# 4891     True
# 4892    False
# 4893    False
# 4894     True
# 4895     True
# 4896     True
# 4897    False
# 4898     True
# 4899     True
# 4900     True
# 4901     True
# 4902     True
# 4903     True
# 4904    False
# 4905     True
# 4906     True
# 4907     True
# 4908     True
# 4909     True
# 4910     True
# 4911     True
# 4912     True
# 4913     True
# 4914     True
# 4915     True
# ...

# %%
#(j)
imdb_score <= 6
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28       True
# 29      False
#         ...
# 4886    False
# 4887    False
# 4888    False
# 4889     True
# 4890     True
# 4891    False
# 4892     True
# 4893     True
# 4894    False
# 4895    False
# 4896    False
# 4897     True
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902    False
# 4903    False
# 4904     True
# 4905    False
# 4906    False
# 4907    False
# 4908    False
# 4909    False
# 4910    False
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
#(k)
imdb_score >= 5
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 4886     True
# 4887     True
# 4888     True
# 4889    False
# 4890    False
# 4891     True
# 4892    False
# 4893    False
# 4894     True
# 4895     True
# 4896     True
# 4897    False
# 4898     True
# 4899     True
# 4900     True
# 4901     True
# 4902     True
# 4903     True
# 4904     True
# 4905     True
# 4906     True
# 4907     True
# 4908     True
# 4909     True
# 4910     True
# 4911     True
# 4912     True
# 4913     True
# 4914     True
# 4915     True
# ...

# %%
#(l)
imdb_score == 7
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21       True
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29       True
#         ...
# 4886     True
# 4887    False
# 4888    False
# 4889    False
# 4890    False
# 4891    False
# 4892    False
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902    False
# 4903    False
# 4904    False
# 4905    False
# 4906     True
# 4907    False
# 4908    False
# 4909    False
# 4910    False
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# ...

# %%
#(m)
imdb_score != 7
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21      False
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29      False
#         ...
# 4886    False
# 4887     True
# 4888     True
# 4889     True
# 4890     True
# 4891     True
# 4892     True
# 4893     True
# 4894     True
# 4895     True
# 4896     True
# 4897     True
# 4898     True
# 4899     True
# 4900     True
# 4901     True
# 4902     True
# 4903     True
# 4904     True
# 4905     True
# 4906    False
# 4907     True
# 4908     True
# 4909     True
# 4910     True
# 4911     True
# 4912     True
# 4913     True
# 4914     True
# 4915     True
# ...

# %% [markdown]
# 15. Rename the column director_name as Director Name:

# %%
import pandas as pd
movie = pd.read_csv('movie.csv')
col_rename = {'director_name':'Director Name'}
movie_renamed = movie.rename(columns = col_rename)
movie_renamed.head()
# Out:
#    color      Director Name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0       Rory Kinner
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# Q.8. Difference between mul() and * (in series).

# %% [markdown]
# Ans.An operator (*) only operates in exactly one manner.
# Method, on other hand, can have parameters that allow you to alter their default functionaity

# %% [markdown]
# Q.9.What are special method? Explain with example.

# %% [markdown]
# Ans.Python has a built-in,standarized way for objects to communicate with operator using special methods.

# %% [markdown]
# There is no difference between using the special methods

# %% [markdown]
# Q.10.What is method chaining.Explainwith example.

# %% [markdown]
# Ans.The sequential invocation of methods using the dot notation is reffered to as method chaning

# %% [markdown]
# Q.11.How can you count the number of missing values in a series.

# %%
director.isnull()
director.count()
# Out:
# 4814

# %% [markdown]
# Q.12.How can you find the percentage of missing value in a series.

# %%
Ans.
# Out:
#   File "<ipython-input-112-44247077a1c9>", line 1
#     Ans.
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Q.13.What is method chaning? What are its disadvantage?

# %% [markdown]
# Ans.The sequential invocation of methods using the dot notation is reffered to as method chaning

# %% [markdown]
# First disadvantage of that debugging becomes difficult.
# None of the intermidiate objectcs produced during the chain are stored in a variable, so if there is an unexpected result, it will be difficult to trace the exact location in the chain where it occured.

# %% [markdown]
# Q.14.Explain the use of index_col parameter of read_csv() method with an example.

# %% [markdown]
# Ans.To choose a column as the index upon initial read with the read_csv function:

# %%
movie = pd.read_csv('movie.csv',index_col= 'movie_title')

# %%
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %% [markdown]
# Q.16.There are several columns that contain data on the number of Facebook likes.
# Create a new column named'FB_LIKES_TOTAL',which will contain the sum of all such columns.

# %%
movie['FB_LIKES_TOTAL']=\
     (movie['actor_1_facebook_likes']+
      movie['actor_2_facebook_likes']+
      movie['actor_3_facebook_likes'])
movie
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %% [markdown]
# Q.17. Delete the column FB_LIKES_TOTAL.

# %%
del movie['FB_LIKES_TOTAL']
movie
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %% [markdown]
# 18. Add another column that will show the profit the movies has made.

# %%
profit = movie['gross']-movie['budget']
profit1 = profit<0
profit1
# Out:
# movie_title
# Avatar                                         False
# Pirates of the Caribbean: At World's End       False
# Spectre                                         True
# The Dark Knight Rises                          False
# Star Wars: Episode VII - The Force Awakens     False
# John Carter                                     True
# Spider-Man 3                                   False
# Tangled                                         True
# Avengers: Age of Ultron                        False
# Harry Potter and the Half-Blood Prince         False
# Batman v Superman: Dawn of Justice             False
# Superman Returns                                True
# Quantum of Solace                               True
# Pirates of the Caribbean: Dead Man's Chest     False
# The Lone Ranger                                 True
# Man of Steel                                   False
# The Chronicles of Narnia: Prince Caspian        True
# ...
