# %% [markdown]
# Q.1.Demonstrate with example, how you can select (a)one column (b)two columns of DF.

# %%
import pandas as pd 
movie = pd.read_csv('../data/movie.csv')
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0       Rory Kinner
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie.shape
# Out:
# (4916, 28)

# %%
#(a)
director = movie[['director_name']]
director.head()
# Out:
#        director_name
# 0      James Cameron
# 1     Gore Verbinski
# 2         Sam Mendes
# 3  Christopher Nolan
# 4        Doug Walker

# %%
#(b)
director = movie[['director_name','duration']]
director.head()
# Out:
#        director_name  duration
# 0      James Cameron     178.0
# 1     Gore Verbinski     169.0
# 2         Sam Mendes     148.0
# 3  Christopher Nolan     164.0
# 4        Doug Walker       NaN

# %% [markdown]
# Q.2.What will happen when you pass (a) a string (b) a list into the indexing operatorof DF

# %% [markdown]
# #(a)
# When we pass the string into the indexing operator of DF,
# then print the same column which is passes into indexing operator.
# Types of DataFrame is series

# %%
#eg.
director = movie['director_name']
type(director)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #(b)
# When we pass the list into the indexing operator of DF,
# then print the same columns which is passes into indexing operator.
# Types of DataFrame is DataFrame

# %%
#eg.
director = movie[['director_name','duration']]
type(director)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Q.3.Select a single column from a DF in such a way that the result is also a DF.

# %%
director = movie[['director_name']]
director.head()
# Out:
#        director_name
# 0      James Cameron
# 1     Gore Verbinski
# 2         Sam Mendes
# 3  Christopher Nolan
# 4        Doug Walker

# %%
type(director)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Q.4.Give two common reasons for KeyError in a DF.

# %% [markdown]
# We pass the string into the indexing operator of DF and this string is not present the DF,
# then we have KeyError

# %% [markdown]
# Q.5.Explain how you can select columns of a DF using (a) Indexing operator (b) select_dtype()
# and filter() methods.

# %%
#(a)
director = movie[['director_name','duration']]
director.head()
# Out:
#        director_name  duration
# 0      James Cameron     178.0
# 1     Gore Verbinski     169.0
# 2         Sam Mendes     148.0
# 3  Christopher Nolan     164.0
# 4        Doug Walker       NaN

# %%
#(b)
import pandas as pd
movie = pd.read_csv('../data/movie.csv')
movie.get_dtype_counts()
# Out:
# float64    13
# int64       3
# object     12
# dtype: int64

# %% [markdown]
#  This method
# is flexible and searches column names based on which
# parameter is used. Here, we use the like parameter to search for all column
# names that contain the exact string, facebook:

# %%
#(c)
movie.filter(like = 'facebook').head()
# Out:
#    director_facebook_likes  actor_3_facebook_likes  actor_1_facebook_likes  \
# 0                      0.0                   855.0                  1000.0
# 1                    563.0                  1000.0                 40000.0
# 2                      0.0                   161.0                 11000.0
# 3                  22000.0                 23000.0                 27000.0
# 4                    131.0                     NaN                   131.0
#
#    cast_total_facebook_likes  actor_2_facebook_likes  movie_facebook_likes
# 0                       4834                   936.0                 33000
# 1                      48350                  5000.0                     0
# 2                      11700                   393.0                 85000
# 3                     106759                 23000.0                164000
# 4                        143                    12.0                     0

# %% [markdown]
# Q.6.Output the number of columns with each specific data type in a DF.

# %%
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# Q.7.Explain one main difference between select_dtypes() and filter methods.

# %% [markdown]
# Ans.The 'select_dtypes' method takes a list of data types in its include parameterand return a DataFrame with columns is just those given data types.
# This list values may be either the string name of data type or the actual Python object.

# %% [markdown]
# (select_dtype method to select only integer columns )

# %% [markdown]
# filter method is flexible and searches columns names based on which parameter to used.

# %% [markdown]
# Q.8. Explain the difference among like parameter and regex parameter and items
# parameter used in filter method in a DF.

# %% [markdown]
# Ans.like parameter to search for all column names that contain the exact string.

# %%
movie.filter(like = 'facebook').head()
# Out:
#    director_facebook_likes  actor_3_facebook_likes  actor_1_facebook_likes  \
# 0                      0.0                   855.0                  1000.0
# 1                    563.0                  1000.0                 40000.0
# 2                      0.0                   161.0                 11000.0
# 3                  22000.0                 23000.0                 27000.0
# 4                    131.0                     NaN                   131.0
#
#    cast_total_facebook_likes  actor_2_facebook_likes  movie_facebook_likes
# 0                       4834                   936.0                 33000
# 1                      48350                  5000.0                     0
# 2                      11700                   393.0                 85000
# 3                     106759                 23000.0                164000
# 4                        143                    12.0                     0

# %% [markdown]
# regex parameter to search for all column that have a digit somewhere in their name:

# %%
movie.filter(regex = '\d').head()
# Out:
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
# 2                   161.0       Rory Kinner                 11000.0
# 3                 23000.0    Christian Bale                 27000.0
# 4                     NaN        Rob Walker                   131.0
#
#       actor_1_name          actor_3_name  actor_2_facebook_likes
# 0      CCH Pounder             Wes Studi                   936.0
# 1      Johnny Depp        Jack Davenport                  5000.0
# 2  Christoph Waltz      Stephanie Sigman                   393.0
# 3        Tom Hardy  Joseph Gordon-Levitt                 23000.0
# 4      Doug Walker                   NaN                    12.0

# %% [markdown]
# items parameter to search a list of exact column names

# %%
movie.filter(items = ['actor_1_name','asdf']).head()
# Out:
#       actor_1_name
# 0      CCH Pounder
# 1      Johnny Depp
# 2  Christoph Waltz
# 3        Tom Hardy
# 4      Doug Walker

# %% [markdown]
# Q.9. Search for all the columns that have a special character somewhere in their name.

# %% [markdown]
# Q.10. What will happen if you provide a non-existing column name in the indexing operator of a DF?

# %% [markdown]
# Ans. If we provide a non-existing column name in the indexing operator of a DF, It gives Keyerror.

# %% [markdown]
# Q.11.What will happen if you provide a non-existing column name in the list parameter of filter
# method in a DF?

# %% [markdown]
# Ans.

# %%
movie.filter(like = 'parameter').head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# Q.12.Display rows with any NaN value.

# %% [markdown]
# Q.13.Do you think it is useful to arrange the column names sensibly? List the guidelines to arrange
# the columns.

# %% [markdown]
# Ans.Yes,Because its far easier to find and interpret information when columnorder is given consideration.

# %% [markdown]
# Guidlines to order columns

# %% [markdown]
# #Classify each column as either discrete or continuous.

# %% [markdown]
# #Group common columns within the discrete and continuous columns.

# %% [markdown]
# #Place the most impotant groups of columns first with categorical columns before continuous ones.

# %% [markdown]
# Q.14.Write the difference between discrete and continuous variables in DF.

# %% [markdown]
# Q.15. What is Primary Key and Foreign Key in Relational Database.

# %% [markdown]
# Ans.Primary Key - A column or group of columns in a table which helps us to uniquely identifies every row in that table is called a primary key.

# %% [markdown]
#  This DBMS can't be a duplicate. The same value can't appear more than once in the table.

# %% [markdown]
# Foreign Key - A foreign key is a column which is added to create a relationship with another table.

# %% [markdown]
# Foreign keys help us to maintain data integrity and also allows navigation between two different instances of an entity.

# %% [markdown]
# Every relationship in the model needs to be supported by a foreign key.

# %% [markdown]
# Q.16.. While ordering (arranging) the column name, where will you place the Primary Key and the
# Foreign Key of the data ?

# %% [markdown]
# Do all the datasets have Primary and Foreign Keys ?

# %% [markdown]
# Q.17 List the basic descriptive attributes and their functions with examples.

# %% [markdown]
# Ans.Basic Descriptive attributes : shape,size and ndim

# %%
movie = pd.read_csv('../data/movie.csv',index_col = 'director_name')
movie
# Out:
#                               color  num_critic_for_reviews  duration  \
# director_name
# James Cameron                 Color                   723.0     178.0
# Gore Verbinski                Color                   302.0     169.0
# Sam Mendes                    Color                   602.0     148.0
# Christopher Nolan             Color                   813.0     164.0
# Doug Walker                     NaN                     NaN       NaN
# Andrew Stanton                Color                   462.0     132.0
# Sam Raimi                     Color                   392.0     156.0
# Nathan Greno                  Color                   324.0     100.0
# Joss Whedon                   Color                   635.0     141.0
# David Yates                   Color                   375.0     153.0
# Zack Snyder                   Color                   673.0     183.0
# Bryan Singer                  Color                   434.0     169.0
# ...

# %%
movie.shape
# Out:
# (4916, 27)

# %%
movie.size
# Out:
# 132732

# %%
movie.ndim
# Out:
# 2

# %% [markdown]
#     Basic descriptive function : len()

# %%
len(movie)
# Out:
# 4916

# %% [markdown]
# Q.18. Demonstrate the function of len() method.

# %% [markdown]
# Ans. len function to return the number of rows.

# %% [markdown]
# 19. How can you find the number of non-missing values for each column of a DF ?

# %% [markdown]
# Ans.count() method to find the number of non-missing values for each column of a DF.

# %% [markdown]
# Q.20.List all the methods that compute statistics. Demonstrate their use with examples.

# %% [markdown]
# Ans.Following the method of that compute statistics.

# %% [markdown]
# (a): mean()

# %% [markdown]
# (b):std()

# %% [markdown]
# (c):min()

# %% [markdown]
# (d):max()

# %% [markdown]
# (e):percentiles()

# %% [markdown]
# Examples:

# %%
#(a):
movie.mean()
# Out:
# num_critic_for_reviews       1.379889e+02
# duration                     1.070908e+02
# director_facebook_likes      6.910145e+02
# actor_3_facebook_likes       6.312763e+02
# actor_1_facebook_likes       6.494488e+03
# gross                        4.764451e+07
# num_voted_users              8.264492e+04
# cast_total_facebook_likes    9.579816e+03
# facenumber_in_poster         1.377320e+00
# num_user_for_reviews         2.676688e+02
# budget                       3.654749e+07
# title_year                   2.002448e+03
# actor_2_facebook_likes       1.621924e+03
# imdb_score                   6.437429e+00
# aspect_ratio                 2.222349e+00
# movie_facebook_likes         7.348294e+03
# dtype: float64

# %%
#(b)
movie.std()
# Out:
# num_critic_for_reviews       1.202394e+02
# duration                     2.528602e+01
# director_facebook_likes      2.832954e+03
# actor_3_facebook_likes       1.625875e+03
# actor_1_facebook_likes       1.510699e+04
# gross                        6.737255e+07
# num_voted_users              1.383222e+05
# cast_total_facebook_likes    1.816432e+04
# facenumber_in_poster         2.023826e+00
# num_user_for_reviews         3.729348e+02
# budget                       1.002427e+08
# title_year                   1.245398e+01
# actor_2_facebook_likes       4.011300e+03
# imdb_score                   1.127802e+00
# aspect_ratio                 1.402940e+00
# movie_facebook_likes         1.920602e+04
# dtype: float64

# %%
#(c):
movie.min()
# Out:
# num_critic_for_reviews          1.00
# duration                        7.00
# director_facebook_likes         0.00
# actor_3_facebook_likes          0.00
# actor_1_facebook_likes          0.00
# gross                         162.00
# num_voted_users                 5.00
# cast_total_facebook_likes       0.00
# facenumber_in_poster            0.00
# num_user_for_reviews            1.00
# budget                        218.00
# title_year                   1916.00
# actor_2_facebook_likes          0.00
# imdb_score                      1.60
# aspect_ratio                    1.18
# movie_facebook_likes            0.00
# dtype: float64

# %%
#(d):
movie.max()
# Out:
# num_critic_for_reviews       8.130000e+02
# duration                     5.110000e+02
# director_facebook_likes      2.300000e+04
# actor_3_facebook_likes       2.300000e+04
# actor_1_facebook_likes       6.400000e+05
# gross                        7.605058e+08
# num_voted_users              1.689764e+06
# cast_total_facebook_likes    6.567300e+05
# facenumber_in_poster         4.300000e+01
# num_user_for_reviews         5.060000e+03
# budget                       4.200000e+09
# title_year                   2.016000e+03
# actor_2_facebook_likes       1.370000e+05
# imdb_score                   9.500000e+00
# aspect_ratio                 1.600000e+01
# movie_facebook_likes         3.490000e+05
# dtype: float64

# %%
#(e):
movie.describe(percentiles=[.01,.3,.99])
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 1%                   2.000000    43.000000                 0.000000
# 30%                 60.000000    95.000000                11.000000
# 50%                108.000000   103.000000                48.000000
# 99%                546.680000   189.000000             16000.000000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# ...

# %%
movie.quantile(.25)
# Out:
# num_critic_for_reviews            49.00
# duration                          93.00
# director_facebook_likes            7.00
# actor_3_facebook_likes           132.00
# actor_1_facebook_likes           607.00
# gross                        5019656.25
# num_voted_users                 8361.75
# cast_total_facebook_likes       1394.75
# facenumber_in_poster               0.00
# num_user_for_reviews              64.00
# budget                       6000000.00
# title_year                      1999.00
# actor_2_facebook_likes           277.00
# imdb_score                         5.80
# aspect_ratio                       1.85
# movie_facebook_likes               0.00
# Name: 0.25, dtype: float64

# %%
movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %% [markdown]
# 21.How does Pandas deal with the missing values while computing statistics?

# %%
movie.min(skipna=False)
# Out:
# num_critic_for_reviews       NaN
# duration                     NaN
# director_facebook_likes      NaN
# actor_3_facebook_likes       NaN
# actor_1_facebook_likes       NaN
# gross                        NaN
# num_voted_users              5.0
# cast_total_facebook_likes    0.0
# facenumber_in_poster         NaN
# num_user_for_reviews         NaN
# budget                       NaN
# title_year                   NaN
# actor_2_facebook_likes       NaN
# imdb_score                   1.6
# aspect_ratio                 NaN
# movie_facebook_likes         0.0
# dtype: float64
