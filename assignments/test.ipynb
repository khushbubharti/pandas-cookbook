# %%
import pandas as pd 
movie = pd.read_csv('../data/movie.csv')
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0       Rory Kinner
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie = pd.read_csv('movie.csv')
movie1 = movie[['movie_title','imdb_score']]
movie1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7616e1caead0> in <module>
# ----> 1 movie = pd.read_csv('movie.csv')
#       2 movie1 = movie[['movie_title','imdb_score']]
#       3 movie1
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
movie1.nlargest(5,'imdb_score').head()

# %%
movie = pd.read_csv('movie.csv',index_col = 'movie_title')
movie

# %% [markdown]
# write a program to find the sum of numbers from a to b.

# %%
####
import pandas as pd 
movie = pd.read_csv('movie.csv')
movie.head()

# %%
#4
movie.shape

# %%
#1
movie_col = movie.columns
movie_col

# %%
### 2
movie = movie.info()

# %%
#3
movie = pd.read_csv('movie.csv')
movie_row = movie.iloc[[2]]
movie_row

# %%
movie_row = list(movie.iloc[3])
movie_row

# %%
movie_row = movie.iloc[3]
movie_row

# %%
movie.size

# %%
#7
movie_5 = movie.iloc[6]
movie_5

# %%
#9
movie_10 = movie.iloc[[:,9]]
movie_10

# %%
#5
movie = pd.read_csv('movie.csv')
movie1 = movie[['title_year','genres']]
movie1

# %%
movie = pd.read_csv('movie.csv',index_col = 'movie_title')
#movie1 = movie[['movie_title','imdb_score']]
movie

# %%
movie = movie.iloc[[4]]
movie

# %%
#9
movie = pd.read_csv('movie.csv', index_col='movie_title')
movie[0:10:1]

# %%
#16
movie[(movie['duration']>120) & (movie['duration']<160)]['duration']

# %%
import pandas as pd
movie = pd.read_csv('movie.csv')
movie_hours = movie['duration']>120
movie_hours.head()

# %%
movie.info()

# %%
movie.duration.max()

# %%
movie.duration.min()

# %%
import numpy as np

# %%
pd.isna(movie.duration).sum()

# %%
movie.sort_values(by= 'duration', ascending= False)

# %%
movie[(10000000<movie.gross) & (movie.budget<10000000)]

# %%
movie.sort_values(by= 'title_year', ascending= True)

# %%
movie.set_index('genres')

# %%
movie.isnull().sum()

# %%
movie.isnull().any()

# %%
movie.count()

# %%
movie.describe()

# %%
movie.mean()

# %%
movie.min()

# %%
movie.max()

# %%
movie.std()

# %%
movie.get_dtype_counts()

# %%
type(movie)

# %%
movie['new_col']=9
movie
# Out:
#                 color       director_name  num_critic_for_reviews  duration  \
# 0               Color       James Cameron                   723.0     178.0
# 1               Color      Gore Verbinski                   302.0     169.0
# 2               Color          Sam Mendes                   602.0     148.0
# 3               Color   Christopher Nolan                   813.0     164.0
# 4                 NaN         Doug Walker                     NaN       NaN
# 5               Color      Andrew Stanton                   462.0     132.0
# 6               Color           Sam Raimi                   392.0     156.0
# 7               Color        Nathan Greno                   324.0     100.0
# 8               Color         Joss Whedon                   635.0     141.0
# 9               Color         David Yates                   375.0     153.0
# 10              Color         Zack Snyder                   673.0     183.0
# ...

# %%
movie['actor_2_facebook_likes']=movie['actor_2_facebook_likes']
movie['actor_2_facebook_likes']
# Out:
# 0        1874.0
# 1       10002.0
# 2         788.0
# 3       46002.0
# 4          26.0
# 5        1266.0
# 6       22002.0
# 7        1108.0
# 8       42002.0
# 9       22002.0
# 10       8002.0
# 11      20002.0
# 12        826.0
# 13      10002.0
# 14       4002.0
# 15       6002.0
# 16        434.0
# 17      42002.0
# 18      22002.0
# 19       1634.0
# 20       1946.0
# 21      20002.0
# 22       1766.0
# 23       1946.0
# 24      12002.0
# 25       1840.0
# 26      28002.0
# 27      38002.0
# 28      20002.0
# 29       4002.0
#          ...
# 4886       94.0
# 4887     1838.0
# 4888        2.0
# 4889       52.0
# 4890      370.0
# 4891      100.0
# 4892     1026.0
# 4893       40.0
# 4894      450.0
# 4895       40.0
# 4896      426.0
# 4897      184.0
# 4898      288.0
# 4899      268.0
# 4900        2.0
# 4901       12.0
# 4902       28.0
# 4903       42.0
# 4904      198.0
# 4905      390.0
# 4906       92.0
# 4907        2.0
# 4908       42.0
# 4909       90.0
# ...

# %%
movie['facebook_actors']=movie[['actor_3_facebook_likes']+['actor_2_facebook_likes']+['actor_3_facebook_likes']
movie['facebook_actors']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# ...
